# %%
# started at 6:10pm
# paused at 6:49pm
# resumed at 7:07
# stopped at 8:16

# %%
def mul(x,y):
    return x * y

# %%
def get_num_x(file): # if returns "break" then break
    num = ""
    while 1:
        next_char = file.read(1)
        num += next_char
        # print(num + " num outside")
        # print(next_char)
        # if next_char == ')':
        #     print(num + " inside ) statement")
        #     return int(num[0:(len(num)-1)])
        if next_char == 'm':
            return 0
        if next_char != ',':
            try:
                int(num)
            except ValueError:
                group = file.read(4)
                return 0
        # elif next_char == ')':
        #     print(num + " inside ) statement")
        #     return int(num[0:(len(num)-1)])
        else:
            return int(num[0:(len(num)-1)])
    print("hit outside return")
    return

# %%
def get_num_y(file): # if returns "break" then break
    num = ""
    while 1:
        next_char = file.read(1)
        num += next_char
        print(num + " num outside")
        print(next_char)
        # if next_char == ')':
        #     print(num + " inside ) statement")
        #     return int(num[0:(len(num)-1)])
        if next_char == 'm':
            print("hits m return")
            return 0
        if next_char == ')':
            print("hits normal return")
            print(int(num[0:(len(num)-1)]))
            return int(num[0:(len(num)-1)])
        else:
            try:
                int(num)
            except ValueError:
                group = file.read(4)
                print("hits value error return")
                return 0
        # if next_char != ')':
        #     try:
        #         int(num)
        #     except ValueError:
        #         group = file.read(4)
        #         return
        # else:
        #     return int(num[0:(len(num)-1)])
    print("hit outside return")
    return

# %%
file = open("day_three_data.txt", 'r')

# %%
group = file.read(4)
tot = 0
while 1: # loop to find inital "mul("
    if group != "mul(":
        group = group[1:4] + file.read(1)
    else:
        x,y = 0,0
        x = get_num_x(file)
        print(f"{x} is x")
        if x == 0:
            group = file.read(4)
        y = get_num_y(file)
        print(f"{y} is y")
        if y == 0:
            group = file.read(4)
        # closing_parenthesis = file.read(1)
        # print(f"x:{x}, y:{y}")
        if (x != 0) & (y != 0):
            # print("runs tot add")
            tot += mul(x,y)
            group = file.read(4)
        else:
            # print("runs skip")
            group = file.read(4)
    if group == '':
        break
print(tot)
# Out:
# 764 is x
# 4 num outside
# 4
# 40 num outside
# 0
# 406 num outside
# 6
# 406) num outside
# )
# hits normal return
# 406
# 406 is y
# 69 is x
# 4 num outside
# 4
# 49 num outside
# 9
# 497 num outside
# 7
# 497) num outside
# )
# hits normal return
# 497
# 497 is y
# 629 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 650 num outside
# 0
# 650) num outside
# )
# hits normal return
# 650
# 650 is y
# 658 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 217 num outside
# 7
# 217) num outside
# )
# hits normal return
# 217
# 217 is y
# 553 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 521 num outside
# 1
# 521) num outside
# )
# hits normal return
# 521
# 521 is y
# 927 is x
# 1 num outside
# 1
# 17 num outside
# 7
# 175 num outside
# 5
# 175) num outside
# )
# hits normal return
# 175
# 175 is y
# 364 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 814 num outside
# 4
# 814) num outside
# )
# hits normal return
# 814
# 814 is y
# 333 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 471 num outside
# 1
# 471) num outside
# )
# hits normal return
# 471
# 471 is y
# 754 is x
# 7 num outside
# 7
# 71 num outside
# 1
# 711 num outside
# 1
# 711) num outside
# )
# hits normal return
# 711
# 711 is y
# 148 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 921 num outside
# 1
# 921) num outside
# )
# hits normal return
# 921
# 921 is y
# 455 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 877 num outside
# 7
# 877) num outside
# )
# hits normal return
# 877
# 877 is y
# 870 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 745 num outside
# 5
# 745) num outside
# )
# hits normal return
# 745
# 745 is y
# 92 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 899 num outside
# 9
# 899) num outside
# )
# hits normal return
# 899
# 899 is y
# 301 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 362 num outside
# 2
# 362) num outside
# )
# hits normal return
# 362
# 362 is y
# 408 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 781 num outside
# 1
# 781) num outside
# )
# hits normal return
# 781
# 781 is y
# 318 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 503 num outside
# 3
# 503) num outside
# )
# hits normal return
# 503
# 503 is y
# 814 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 611 num outside
# 1
# 611) num outside
# )
# hits normal return
# 611
# 611 is y
# 228 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 415 num outside
# 5
# 415) num outside
# )
# hits normal return
# 415
# 415 is y
# 344 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 298 num outside
# 8
# 298) num outside
# )
# hits normal return
# 298
# 298 is y
# 636 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 572 num outside
# 2
# 572) num outside
# )
# hits normal return
# 572
# 572 is y
# 215 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 309 num outside
# 9
# 309) num outside
# )
# hits normal return
# 309
# 309 is y
# 792 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 335 num outside
# 5
# 335) num outside
# )
# hits normal return
# 335
# 335 is y
# 525 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 151 num outside
# 1
# 151) num outside
# )
# hits normal return
# 151
# 151 is y
# 306 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 819 num outside
# 9
# 819) num outside
# )
# hits normal return
# 819
# 819 is y
# 294 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 958 num outside
# 8
# 958) num outside
# )
# hits normal return
# 958
# 958 is y
# 194 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 339 num outside
# 9
# 339) num outside
# )
# hits normal return
# 339
# 339 is y
# 98 is x
# 9 num outside
# 9
# 91 num outside
# 1
# 917 num outside
# 7
# 917) num outside
# )
# hits normal return
# 917
# 917 is y
# 133 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 311 num outside
# 1
# 311) num outside
# )
# hits normal return
# 311
# 311 is y
# 457 is x
# 9 num outside
# 9
# 98 num outside
# 8
# 981 num outside
# 1
# 981) num outside
# )
# hits normal return
# 981
# 981 is y
# 667 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 837 num outside
# 7
# 837) num outside
# )
# hits normal return
# 837
# 837 is y
# 274 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 151 num outside
# 1
# 151) num outside
# )
# hits normal return
# 151
# 151 is y
# 84 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 363 num outside
# 3
# 363) num outside
# )
# hits normal return
# 363
# 363 is y
# 711 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 25) num outside
# )
# hits normal return
# 25
# 25 is y
# 31 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 323 num outside
# 3
# 323) num outside
# )
# hits normal return
# 323
# 323 is y
# 85 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 830 num outside
# 0
# 830) num outside
# )
# hits normal return
# 830
# 830 is y
# 404 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 568 num outside
# 8
# 568) num outside
# )
# hits normal return
# 568
# 568 is y
# 238 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 707 num outside
# 7
# 707) num outside
# )
# hits normal return
# 707
# 707 is y
# 603 is x
# 3 num outside
# 3
# 3) num outside
# )
# hits normal return
# 3
# 3 is y
# 827 is x
# 9 num outside
# 9
# 90 num outside
# 0
# 90) num outside
# )
# hits normal return
# 90
# 90 is y
# 288 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 639 num outside
# 9
# 639) num outside
# )
# hits normal return
# 639
# 639 is y
# 278 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 751 num outside
# 1
# 751) num outside
# )
# hits normal return
# 751
# 751 is y
# 970 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 757 num outside
# 7
# 757) num outside
# )
# hits normal return
# 757
# 757 is y
# 36 is x
# 9 num outside
# 9
# 90 num outside
# 0
# 900 num outside
# 0
# 900) num outside
# )
# hits normal return
# 900
# 900 is y
# 835 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 851 num outside
# 1
# 851) num outside
# )
# hits normal return
# 851
# 851 is y
# 908 is x
# 8 num outside
# 8
# 82 num outside
# 2
# 82) num outside
# )
# hits normal return
# 82
# 82 is y
# 452 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 524 num outside
# 4
# 524) num outside
# )
# hits normal return
# 524
# 524 is y
# 491 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 590 num outside
# 0
# 590) num outside
# )
# hits normal return
# 590
# 590 is y
# 333 is x
# 3 num outside
# 3
# 39 num outside
# 9
# 397 num outside
# 7
# 397) num outside
# )
# hits normal return
# 397
# 397 is y
# 615 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 16) num outside
# )
# hits normal return
# 16
# 16 is y
# 132 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 775 num outside
# 5
# 775) num outside
# )
# hits normal return
# 775
# 775 is y
# 203 is x
# 6 num outside
# 6
# 60 num outside
# 0
# 604 num outside
# 4
# 604) num outside
# )
# hits normal return
# 604
# 604 is y
# 731 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 849 num outside
# 9
# 849) num outside
# )
# hits normal return
# 849
# 849 is y
# 329 is x
# 9 num outside
# 9
# 90 num outside
# 0
# 904 num outside
# 4
# 904) num outside
# )
# hits normal return
# 904
# 904 is y
# 644 is x
# 6 num outside
# 6
# 69 num outside
# 9
# 691 num outside
# 1
# 691) num outside
# )
# hits normal return
# 691
# 691 is y
# 942 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 653 num outside
# 3
# 653) num outside
# )
# hits normal return
# 653
# 653 is y
# 676 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 56) num outside
# )
# hits normal return
# 56
# 56 is y
# 6 is x
# 6 num outside
# 6
# 69 num outside
# 9
# 697 num outside
# 7
# 697) num outside
# )
# hits normal return
# 697
# 697 is y
# 369 is x
# 4 num outside
# 4
# 48 num outside
# 8
# 485 num outside
# 5
# 485) num outside
# )
# hits normal return
# 485
# 485 is y
# 593 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 437 num outside
# 7
# 437) num outside
# )
# hits normal return
# 437
# 437 is y
# 587 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 740 num outside
# 0
# 740) num outside
# )
# hits normal return
# 740
# 740 is y
# 544 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 337 num outside
# 7
# 337) num outside
# )
# hits normal return
# 337
# 337 is y
# 528 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 533 num outside
# 3
# 533) num outside
# )
# hits normal return
# 533
# 533 is y
# 418 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 882 num outside
# 2
# 882) num outside
# )
# hits normal return
# 882
# 882 is y
# 991 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 431 num outside
# 1
# 431) num outside
# )
# hits normal return
# 431
# 431 is y
# 30 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 319 num outside
# 9
# 319) num outside
# )
# hits normal return
# 319
# 319 is y
# 968 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 612 num outside
# 2
# 612) num outside
# )
# hits normal return
# 612
# 612 is y
# 261 is x
# 9 num outside
# 9
# 94 num outside
# 4
# 949 num outside
# 9
# 949) num outside
# )
# hits normal return
# 949
# 949 is y
# 745 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 147 num outside
# 7
# 147) num outside
# )
# hits normal return
# 147
# 147 is y
# 759 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 21) num outside
# )
# hits normal return
# 21
# 21 is y
# 319 is x
# 2 num outside
# 2
# 27 num outside
# 7
# 271 num outside
# 1
# 271) num outside
# )
# hits normal return
# 271
# 271 is y
# 580 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 221 num outside
# 1
# 221) num outside
# )
# hits normal return
# 221
# 221 is y
# 345 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 819 num outside
# 9
# 819) num outside
# )
# hits normal return
# 819
# 819 is y
# 433 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 622 num outside
# 2
# 622) num outside
# )
# hits normal return
# 622
# 622 is y
# 83 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 145 num outside
# 5
# 145) num outside
# )
# hits normal return
# 145
# 145 is y
# 609 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 269 num outside
# 9
# 269) num outside
# )
# hits normal return
# 269
# 269 is y
# 741 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 355 num outside
# 5
# 355) num outside
# )
# hits normal return
# 355
# 355 is y
# 850 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 79) num outside
# )
# hits normal return
# 79
# 79 is y
# 944 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 589 num outside
# 9
# 589) num outside
# )
# hits normal return
# 589
# 589 is y
# 152 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 384 num outside
# 4
# 384) num outside
# )
# hits normal return
# 384
# 384 is y
# 969 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 921 num outside
# 1
# 921) num outside
# )
# hits normal return
# 921
# 921 is y
# 283 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 868 num outside
# 8
# 868) num outside
# )
# hits normal return
# 868
# 868 is y
# 243 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 299 num outside
# 9
# 299) num outside
# )
# hits normal return
# 299
# 299 is y
# 399 is x
# 2 num outside
# 2
# 27 num outside
# 7
# 270 num outside
# 0
# 270) num outside
# )
# hits normal return
# 270
# 270 is y
# 402 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 321 num outside
# 1
# 321) num outside
# )
# hits normal return
# 321
# 321 is y
# 345 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 576 num outside
# 6
# 576} num outside
# }
# hits value error return
# 0 is y
# 102 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 637 num outside
# 7
# 637) num outside
# )
# hits normal return
# 637
# 637 is y
# 986 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 145 num outside
# 5
# 145) num outside
# )
# hits normal return
# 145
# 145 is y
# 973 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 528 num outside
# 8
# 528) num outside
# )
# hits normal return
# 528
# 528 is y
# 153 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 242 num outside
# 2
# 242) num outside
# )
# hits normal return
# 242
# 242 is y
# 413 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 240 num outside
# 0
# 240) num outside
# )
# hits normal return
# 240
# 240 is y
# 631 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 220 num outside
# 0
# 220) num outside
# )
# hits normal return
# 220
# 220 is y
# 980 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 831 num outside
# 1
# 831) num outside
# )
# hits normal return
# 831
# 831 is y
# 907 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 168 num outside
# 8
# 168) num outside
# )
# hits normal return
# 168
# 168 is y
# 279 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 745 num outside
# 5
# 745) num outside
# )
# hits normal return
# 745
# 745 is y
# 606 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 720 num outside
# 0
# 720) num outside
# )
# hits normal return
# 720
# 720 is y
# 555 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 14) num outside
# )
# hits normal return
# 14
# 14 is y
# 577 is x
# 3 num outside
# 3
# 37 num outside
# 7
# 376 num outside
# 6
# 376) num outside
# )
# hits normal return
# 376
# 376 is y
# 18 is x
# 3 num outside
# 3
# 37 num outside
# 7
# 375 num outside
# 5
# 375) num outside
# )
# hits normal return
# 375
# 375 is y
# 463 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 674 num outside
# 4
# 674( num outside
# (
# hits value error return
# 0 is y
# 124 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 324 num outside
# 4
# 324) num outside
# )
# hits normal return
# 324
# 324 is y
# 558 is x
# 4 num outside
# 4
# 49 num outside
# 9
# 499 num outside
# 9
# 499) num outside
# )
# hits normal return
# 499
# 499 is y
# 73 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 35) num outside
# )
# hits normal return
# 35
# 35 is y
# 800 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 842 num outside
# 2
# 842) num outside
# )
# hits normal return
# 842
# 842 is y
# 621 is x
# 7 num outside
# 7
# 71 num outside
# 1
# 718 num outside
# 8
# 718) num outside
# )
# hits normal return
# 718
# 718 is y
# 353 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 215 num outside
# 5
# 215) num outside
# )
# hits normal return
# 215
# 215 is y
# 299 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 721 num outside
# 1
# 721) num outside
# )
# hits normal return
# 721
# 721 is y
# 911 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 921 num outside
# 1
# 921) num outside
# )
# hits normal return
# 921
# 921 is y
# 19 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 957 num outside
# 7
# 957) num outside
# )
# hits normal return
# 957
# 957 is y
# 441 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 742 num outside
# 2
# 742) num outside
# )
# hits normal return
# 742
# 742 is y
# 622 is x
# 9 num outside
# 9
# 97 num outside
# 7
# 972 num outside
# 2
# 972{ num outside
# {
# hits value error return
# 0 is y
# 918 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 303 num outside
# 3
# 303) num outside
# )
# hits normal return
# 303
# 303 is y
# 504 is x
# 6 num outside
# 6
# 66 num outside
# 6
# 662 num outside
# 2
# 662) num outside
# )
# hits normal return
# 662
# 662 is y
# 533 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 672 num outside
# 2
# 672) num outside
# )
# hits normal return
# 672
# 672 is y
# 473 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 262 num outside
# 2
# 262) num outside
# )
# hits normal return
# 262
# 262 is y
# 573 is x
# 6 num outside
# 6
# 66 num outside
# 6
# 666 num outside
# 6
# 666) num outside
# )
# hits normal return
# 666
# 666 is y
# 969 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 473 num outside
# 3
# 473) num outside
# )
# hits normal return
# 473
# 473 is y
# 214 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 766 num outside
# 6
# 766) num outside
# )
# hits normal return
# 766
# 766 is y
# 470 is x
# 9 num outside
# 9
# 94 num outside
# 4
# 943 num outside
# 3
# 943) num outside
# )
# hits normal return
# 943
# 943 is y
# 739 is x
# 9 num outside
# 9
# 93 num outside
# 3
# 932 num outside
# 2
# 932) num outside
# )
# hits normal return
# 932
# 932 is y
# 898 is x
# 6 num outside
# 6
# 69 num outside
# 9
# 691 num outside
# 1
# 691) num outside
# )
# hits normal return
# 691
# 691 is y
# 319 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 166 num outside
# 6
# 166- num outside
# -
# hits value error return
# 0 is y
# 72 is x
# 6 num outside
# 6
# 64 num outside
# 4
# 647 num outside
# 7
# 647) num outside
# )
# hits normal return
# 647
# 647 is y
# 985 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 540 num outside
# 0
# 540) num outside
# )
# hits normal return
# 540
# 540 is y
# 736 is x
# 4 num outside
# 4
# 44 num outside
# 4
# 442 num outside
# 2
# 442) num outside
# )
# hits normal return
# 442
# 442 is y
# 476 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 579 num outside
# 9
# 579) num outside
# )
# hits normal return
# 579
# 579 is y
# 7 is x
# 9 num outside
# 9
# 93 num outside
# 3
# 937 num outside
# 7
# 937) num outside
# )
# hits normal return
# 937
# 937 is y
# 755 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 19) num outside
# )
# hits normal return
# 19
# 19 is y
# 80 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 314 num outside
# 4
# 314) num outside
# )
# hits normal return
# 314
# 314 is y
# 563 is x
# 7 num outside
# 7
# 73 num outside
# 3
# 731 num outside
# 1
# 731) num outside
# )
# hits normal return
# 731
# 731 is y
# 285 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 88) num outside
# )
# hits normal return
# 88
# 88 is y
# 569 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 348 num outside
# 8
# 348) num outside
# )
# hits normal return
# 348
# 348 is y
# 919 is x
# 4 num outside
# 4
# 48 num outside
# 8
# 482 num outside
# 2
# 482) num outside
# )
# hits normal return
# 482
# 482 is y
# 275 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 890 num outside
# 0
# 890) num outside
# )
# hits normal return
# 890
# 890 is y
# 689 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 521 num outside
# 1
# 521) num outside
# )
# hits normal return
# 521
# 521 is y
# 116 is x
# 6 num outside
# 6
# 64 num outside
# 4
# 646 num outside
# 6
# 646) num outside
# )
# hits normal return
# 646
# 646 is y
# 0 is x
# r num outside
# r
# hits value error return
# 0 is y
# 473 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 864 num outside
# 4
# 864) num outside
# )
# hits normal return
# 864
# 864 is y
# 943 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 380 num outside
# 0
# 380) num outside
# )
# hits normal return
# 380
# 380 is y
# 352 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 764 num outside
# 4
# 764) num outside
# )
# hits normal return
# 764
# 764 is y
# 939 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 747 num outside
# 7
# 747) num outside
# )
# hits normal return
# 747
# 747 is y
# 770 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 687 num outside
# 7
# 687) num outside
# )
# hits normal return
# 687
# 687 is y
# 289 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 328 num outside
# 8
# 328) num outside
# )
# hits normal return
# 328
# 328 is y
# 52 is x
# 9 num outside
# 9
# 91 num outside
# 1
# 913 num outside
# 3
# 913) num outside
# )
# hits normal return
# 913
# 913 is y
# 324 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 290 num outside
# 0
# 290) num outside
# )
# hits normal return
# 290
# 290 is y
# 711 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 194 num outside
# 4
# 194) num outside
# )
# hits normal return
# 194
# 194 is y
# 675 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 226 num outside
# 6
# 226) num outside
# )
# hits normal return
# 226
# 226 is y
# 111 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 885 num outside
# 5
# 885) num outside
# )
# hits normal return
# 885
# 885 is y
# 580 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 679 num outside
# 9
# 679) num outside
# )
# hits normal return
# 679
# 679 is y
# 464 is x
# 4 num outside
# 4
# 40 num outside
# 0
# 404 num outside
# 4
# 404) num outside
# )
# hits normal return
# 404
# 404 is y
# 828 is x
# 8 num outside
# 8
# 80 num outside
# 0
# 803 num outside
# 3
# 803) num outside
# )
# hits normal return
# 803
# 803 is y
# 809 is x
# 9 num outside
# 9
# 93 num outside
# 3
# 932 num outside
# 2
# 932) num outside
# )
# hits normal return
# 932
# 932 is y
# 624 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 523 num outside
# 3
# 523) num outside
# )
# hits normal return
# 523
# 523 is y
# 952 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 680 num outside
# 0
# 680) num outside
# )
# hits normal return
# 680
# 680 is y
# 966 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 356 num outside
# 6
# 356) num outside
# )
# hits normal return
# 356
# 356 is y
# 552 is x
# 6 num outside
# 6
# 66 num outside
# 6
# 661 num outside
# 1
# 661) num outside
# )
# hits normal return
# 661
# 661 is y
# 841 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 189 num outside
# 9
# 189) num outside
# )
# hits normal return
# 189
# 189 is y
# 684 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 633 num outside
# 3
# 633) num outside
# )
# hits normal return
# 633
# 633 is y
# 912 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 573 num outside
# 3
# 573) num outside
# )
# hits normal return
# 573
# 573 is y
# 745 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 363 num outside
# 3
# 363( num outside
# (
# hits value error return
# 0 is y
# 523 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 857 num outside
# 7
# 857) num outside
# )
# hits normal return
# 857
# 857 is y
# 545 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 863 num outside
# 3
# 863) num outside
# )
# hits normal return
# 863
# 863 is y
# 680 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 541 num outside
# 1
# 541) num outside
# )
# hits normal return
# 541
# 541 is y
# 238 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 859 num outside
# 9
# 859) num outside
# )
# hits normal return
# 859
# 859 is y
# 173 is x
# 1 num outside
# 1
# 10 num outside
# 0
# 105 num outside
# 5
# 105) num outside
# )
# hits normal return
# 105
# 105 is y
# 356 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 774 num outside
# 4
# 774) num outside
# )
# hits normal return
# 774
# 774 is y
# 758 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 332 num outside
# 2
# 332) num outside
# )
# hits normal return
# 332
# 332 is y
# 643 is x
# 4 num outside
# 4
# 44 num outside
# 4
# 442 num outside
# 2
# 442) num outside
# )
# hits normal return
# 442
# 442 is y
# 416 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 167 num outside
# 7
# 167) num outside
# )
# hits normal return
# 167
# 167 is y
# 907 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 888 num outside
# 8
# 888) num outside
# )
# hits normal return
# 888
# 888 is y
# 452 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 595 num outside
# 5
# 595) num outside
# )
# hits normal return
# 595
# 595 is y
# 767 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 194 num outside
# 4
# 194) num outside
# )
# hits normal return
# 194
# 194 is y
# 635 is x
# 1 num outside
# 1
# 12 num outside
# 2
# 124 num outside
# 4
# 124) num outside
# )
# hits normal return
# 124
# 124 is y
# 71 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 301 num outside
# 1
# 301) num outside
# )
# hits normal return
# 301
# 301 is y
# 817 is x
# 4 num outside
# 4
# 46 num outside
# 6
# 468 num outside
# 8
# 468) num outside
# )
# hits normal return
# 468
# 468 is y
# 991 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 655 num outside
# 5
# 655) num outside
# )
# hits normal return
# 655
# 655 is y
# 324 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 148 num outside
# 8
# 148) num outside
# )
# hits normal return
# 148
# 148 is y
# 13 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 538 num outside
# 8
# 538) num outside
# )
# hits normal return
# 538
# 538 is y
# 887 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 419 num outside
# 9
# 419) num outside
# )
# hits normal return
# 419
# 419 is y
# 864 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 345 num outside
# 5
# 345) num outside
# )
# hits normal return
# 345
# 345 is y
# 991 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 25) num outside
# )
# hits normal return
# 25
# 25 is y
# 339 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 86) num outside
# )
# hits normal return
# 86
# 86 is y
# 155 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 613 num outside
# 3
# 613) num outside
# )
# hits normal return
# 613
# 613 is y
# 812 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 654 num outside
# 4
# 654) num outside
# )
# hits normal return
# 654
# 654 is y
# 386 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 847 num outside
# 7
# 847) num outside
# )
# hits normal return
# 847
# 847 is y
# 635 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 220 num outside
# 0
# 220) num outside
# )
# hits normal return
# 220
# 220 is y
# 204 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 503 num outside
# 3
# 503) num outside
# )
# hits normal return
# 503
# 503 is y
# 913 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 575 num outside
# 5
# 575) num outside
# )
# hits normal return
# 575
# 575 is y
# 313 is x
# 9 num outside
# 9
# 96 num outside
# 6
# 960 num outside
# 0
# 960) num outside
# )
# hits normal return
# 960
# 960 is y
# 828 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 212 num outside
# 2
# 212) num outside
# )
# hits normal return
# 212
# 212 is y
# 454 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 310 num outside
# 0
# 310) num outside
# )
# hits normal return
# 310
# 310 is y
# 51 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 471 num outside
# 1
# 471) num outside
# )
# hits normal return
# 471
# 471 is y
# 218 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 841 num outside
# 1
# 841) num outside
# )
# hits normal return
# 841
# 841 is y
# 310 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 68f num outside
# f
# hits value error return
# 0 is y
# 107 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 89) num outside
# )
# hits normal return
# 89
# 89 is y
# 620 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 335 num outside
# 5
# 335) num outside
# )
# hits normal return
# 335
# 335 is y
# 713 is x
# 1 num outside
# 1
# 17 num outside
# 7
# 177 num outside
# 7
# 177) num outside
# )
# hits normal return
# 177
# 177 is y
# 174 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 51) num outside
# )
# hits normal return
# 51
# 51 is y
# 639 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 289 num outside
# 9
# 289) num outside
# )
# hits normal return
# 289
# 289 is y
# 71 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 771 num outside
# 1
# 771) num outside
# )
# hits normal return
# 771
# 771 is y
# 624 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 295 num outside
# 5
# 295) num outside
# )
# hits normal return
# 295
# 295 is y
# 880 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 831 num outside
# 1
# 831) num outside
# )
# hits normal return
# 831
# 831 is y
# 41 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 537 num outside
# 7
# 537) num outside
# )
# hits normal return
# 537
# 537 is y
# 959 is x
# 1 num outside
# 1
# 11 num outside
# 1
# 111 num outside
# 1
# 111) num outside
# )
# hits normal return
# 111
# 111 is y
# 219 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 762 num outside
# 2
# 762) num outside
# )
# hits normal return
# 762
# 762 is y
# 57 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 744 num outside
# 4
# 744) num outside
# )
# hits normal return
# 744
# 744 is y
# 15 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 791 num outside
# 1
# 791) num outside
# )
# hits normal return
# 791
# 791 is y
# 354 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 865 num outside
# 5
# 865) num outside
# )
# hits normal return
# 865
# 865 is y
# 912 is x
# 1 num outside
# 1
# 11 num outside
# 1
# 118 num outside
# 8
# 118) num outside
# )
# hits normal return
# 118
# 118 is y
# 53 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 256 num outside
# 6
# 256) num outside
# )
# hits normal return
# 256
# 256 is y
# 35 is x
# 1 num outside
# 1
# 10 num outside
# 0
# 100 num outside
# 0
# 100) num outside
# )
# hits normal return
# 100
# 100 is y
# 340 is x
# 4 num outside
# 4
# 48 num outside
# 8
# 487 num outside
# 7
# 487) num outside
# )
# hits normal return
# 487
# 487 is y
# 761 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 89) num outside
# )
# hits normal return
# 89
# 89 is y
# 862 is x
# 4 num outside
# 4
# 42 num outside
# 2
# 420 num outside
# 0
# 420) num outside
# )
# hits normal return
# 420
# 420 is y
# 391 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 75) num outside
# )
# hits normal return
# 75
# 75 is y
# 952 is x
# 2 num outside
# 2
# 27 num outside
# 7
# 271 num outside
# 1
# 271) num outside
# )
# hits normal return
# 271
# 271 is y
# 90 is x
# 4 num outside
# 4
# 42 num outside
# 2
# 422 num outside
# 2
# 422) num outside
# )
# hits normal return
# 422
# 422 is y
# 545 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 249 num outside
# 9
# 249) num outside
# )
# hits normal return
# 249
# 249 is y
# 93 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 793 num outside
# 3
# 793) num outside
# )
# hits normal return
# 793
# 793 is y
# 401 is x
# 4 num outside
# 4
# 40 num outside
# 0
# 403 num outside
# 3
# 403) num outside
# )
# hits normal return
# 403
# 403 is y
# 821 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 313 num outside
# 3
# 313) num outside
# )
# hits normal return
# 313
# 313 is y
# 90 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 843 num outside
# 3
# 843) num outside
# )
# hits normal return
# 843
# 843 is y
# 399 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 618 num outside
# 8
# 618) num outside
# )
# hits normal return
# 618
# 618 is y
# 531 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 529 num outside
# 9
# 529) num outside
# )
# hits normal return
# 529
# 529 is y
# 227 is x
# 9 num outside
# 9
# 91 num outside
# 1
# 911 num outside
# 1
# 911) num outside
# )
# hits normal return
# 911
# 911 is y
# 778 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 507 num outside
# 7
# 507) num outside
# )
# hits normal return
# 507
# 507 is y
# 206 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 671 num outside
# 1
# 671) num outside
# )
# hits normal return
# 671
# 671 is y
# 747 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 568 num outside
# 8
# 568) num outside
# )
# hits normal return
# 568
# 568 is y
# 64 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 616 num outside
# 6
# 616) num outside
# )
# hits normal return
# 616
# 616 is y
# 648 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 520 num outside
# 0
# 520) num outside
# )
# hits normal return
# 520
# 520 is y
# 771 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 307 num outside
# 7
# 307( num outside
# (
# hits value error return
# 0 is y
# 72 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 835 num outside
# 5
# 835) num outside
# )
# hits normal return
# 835
# 835 is y
# 203 is x
# 1 num outside
# 1
# 13 num outside
# 3
# 135 num outside
# 5
# 135) num outside
# )
# hits normal return
# 135
# 135 is y
# 24 is x
# 8 num outside
# 8
# 80 num outside
# 0
# 801 num outside
# 1
# 801) num outside
# )
# hits normal return
# 801
# 801 is y
# 875 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 162 num outside
# 2
# 162) num outside
# )
# hits normal return
# 162
# 162 is y
# 127 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 591 num outside
# 1
# 591) num outside
# )
# hits normal return
# 591
# 591 is y
# 732 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 249 num outside
# 9
# 249) num outside
# )
# hits normal return
# 249
# 249 is y
# 407 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 186 num outside
# 6
# 186) num outside
# )
# hits normal return
# 186
# 186 is y
# 461 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 214 num outside
# 4
# 214) num outside
# )
# hits normal return
# 214
# 214 is y
# 650 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 791 num outside
# 1
# 791) num outside
# )
# hits normal return
# 791
# 791 is y
# 200 is x
# 4 num outside
# 4
# 46 num outside
# 6
# 463 num outside
# 3
# 463) num outside
# )
# hits normal return
# 463
# 463 is y
# 970 is x
# 4 num outside
# 4
# 44 num outside
# 4
# 444 num outside
# 4
# 444) num outside
# )
# hits normal return
# 444
# 444 is y
# 236 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 599 num outside
# 9
# 599) num outside
# )
# hits normal return
# 599
# 599 is y
# 259 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 290 num outside
# 0
# 290) num outside
# )
# hits normal return
# 290
# 290 is y
# 698 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 621 num outside
# 1
# 621) num outside
# )
# hits normal return
# 621
# 621 is y
# 458 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 533 num outside
# 3
# 533w num outside
# w
# hits value error return
# 0 is y
# 810 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 353 num outside
# 3
# 353) num outside
# )
# hits normal return
# 353
# 353 is y
# 928 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 260 num outside
# 0
# 260) num outside
# )
# hits normal return
# 260
# 260 is y
# 803 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 627 num outside
# 7
# 627) num outside
# )
# hits normal return
# 627
# 627 is y
# 0 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 784 num outside
# 4
# 784, num outside
# ,
# hits value error return
# 0 is y
# 480 is x
# 3 num outside
# 3
# 39 num outside
# 9
# 39) num outside
# )
# hits normal return
# 39
# 39 is y
# 423 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 817 num outside
# 7
# 817) num outside
# )
# hits normal return
# 817
# 817 is y
# 758 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 858 num outside
# 8
# 858) num outside
# )
# hits normal return
# 858
# 858 is y
# 986 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 262 num outside
# 2
# 262) num outside
# )
# hits normal return
# 262
# 262 is y
# 326 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 89) num outside
# )
# hits normal return
# 89
# 89 is y
# 863 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 330 num outside
# 0
# 330) num outside
# )
# hits normal return
# 330
# 330 is y
# 797 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 517 num outside
# 7
# 517) num outside
# )
# hits normal return
# 517
# 517 is y
# 181 is x
# 9 num outside
# 9
# 91 num outside
# 1
# 911 num outside
# 1
# 911) num outside
# )
# hits normal return
# 911
# 911 is y
# 786 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 389 num outside
# 9
# 389) num outside
# )
# hits normal return
# 389
# 389 is y
# 259 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 624 num outside
# 4
# 624) num outside
# )
# hits normal return
# 624
# 624 is y
# 725 is x
# 1 num outside
# 1
# 17 num outside
# 7
# 17) num outside
# )
# hits normal return
# 17
# 17 is y
# 45 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 704 num outside
# 4
# 704) num outside
# )
# hits normal return
# 704
# 704 is y
# 467 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 742 num outside
# 2
# 742) num outside
# )
# hits normal return
# 742
# 742 is y
# 940 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 529 num outside
# 9
# 529) num outside
# )
# hits normal return
# 529
# 529 is y
# 859 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 621 num outside
# 1
# 621) num outside
# )
# hits normal return
# 621
# 621 is y
# 563 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 851 num outside
# 1
# 851) num outside
# )
# hits normal return
# 851
# 851 is y
# 479 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 727 num outside
# 7
# 727) num outside
# )
# hits normal return
# 727
# 727 is y
# 732 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 842 num outside
# 2
# 842) num outside
# )
# hits normal return
# 842
# 842 is y
# 402 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 340 num outside
# 0
# 340) num outside
# )
# hits normal return
# 340
# 340 is y
# 237 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 505 num outside
# 5
# 505) num outside
# )
# hits normal return
# 505
# 505 is y
# 94 is x
# 1 num outside
# 1
# 12 num outside
# 2
# 128 num outside
# 8
# 128) num outside
# )
# hits normal return
# 128
# 128 is y
# 575 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 722 num outside
# 2
# 722) num outside
# )
# hits normal return
# 722
# 722 is y
# 688 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 182 num outside
# 2
# 182) num outside
# )
# hits normal return
# 182
# 182 is y
# 256 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 256 num outside
# 6
# 256) num outside
# )
# hits normal return
# 256
# 256 is y
# 905 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 458 num outside
# 8
# 458) num outside
# )
# hits normal return
# 458
# 458 is y
# 105 is x
# 7 num outside
# 7
# 71 num outside
# 1
# 710 num outside
# 0
# 710) num outside
# )
# hits normal return
# 710
# 710 is y
# 316 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 625 num outside
# 5
# 625) num outside
# )
# hits normal return
# 625
# 625 is y
# 660 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 344 num outside
# 4
# 344) num outside
# )
# hits normal return
# 344
# 344 is y
# 588 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 300 num outside
# 0
# 300) num outside
# )
# hits normal return
# 300
# 300 is y
# 552 is x
# 1 num outside
# 1
# 11 num outside
# 1
# 113 num outside
# 3
# 113) num outside
# )
# hits normal return
# 113
# 113 is y
# 815 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 752 num outside
# 2
# 752) num outside
# )
# hits normal return
# 752
# 752 is y
# 681 is x
# 5 num outside
# 5
# 55 num outside
# 5
# 55) num outside
# )
# hits normal return
# 55
# 55 is y
# 869 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 410 num outside
# 0
# 410) num outside
# )
# hits normal return
# 410
# 410 is y
# 153 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 766 num outside
# 6
# 766) num outside
# )
# hits normal return
# 766
# 766 is y
# 30 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 619 num outside
# 9
# 619) num outside
# )
# hits normal return
# 619
# 619 is y
# 249 is x
# 8 num outside
# 8
# 82 num outside
# 2
# 820 num outside
# 0
# 820) num outside
# )
# hits normal return
# 820
# 820 is y
# 782 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 869 num outside
# 9
# 869) num outside
# )
# hits normal return
# 869
# 869 is y
# 955 is x
# 8 num outside
# 8
# 89 num outside
# 9
# 896 num outside
# 6
# 896) num outside
# )
# hits normal return
# 896
# 896 is y
# 198 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 43) num outside
# )
# hits normal return
# 43
# 43 is y
# 570 is x
# 6 num outside
# 6
# 60 num outside
# 0
# 606 num outside
# 6
# 606) num outside
# )
# hits normal return
# 606
# 606 is y
# 148 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 451 num outside
# 1
# 451) num outside
# )
# hits normal return
# 451
# 451 is y
# 868 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 83) num outside
# )
# hits normal return
# 83
# 83 is y
# 627 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 221 num outside
# 1
# 221) num outside
# )
# hits normal return
# 221
# 221 is y
# 420 is x
# 1 num outside
# 1
# 11 num outside
# 1
# 115 num outside
# 5
# 115) num outside
# )
# hits normal return
# 115
# 115 is y
# 217 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 876 num outside
# 6
# 876) num outside
# )
# hits normal return
# 876
# 876 is y
# 459 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 584 num outside
# 4
# 584) num outside
# )
# hits normal return
# 584
# 584 is y
# 119 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 326 num outside
# 6
# 326) num outside
# )
# hits normal return
# 326
# 326 is y
# 95 is x
# 8 num outside
# 8
# 80 num outside
# 0
# 805 num outside
# 5
# 805[ num outside
# [
# hits value error return
# 0 is y
# 855 is x
# 6 num outside
# 6
# 69 num outside
# 9
# 692 num outside
# 2
# 692) num outside
# )
# hits normal return
# 692
# 692 is y
# 246 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 352 num outside
# 2
# 352) num outside
# )
# hits normal return
# 352
# 352 is y
# 254 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 154 num outside
# 4
# 154) num outside
# )
# hits normal return
# 154
# 154 is y
# 877 is x
# 4 num outside
# 4
# 46 num outside
# 6
# 465 num outside
# 5
# 465& num outside
# &
# hits value error return
# 0 is y
# 170 is x
# 5 num outside
# 5
# 55 num outside
# 5
# 554 num outside
# 4
# 554) num outside
# )
# hits normal return
# 554
# 554 is y
# 627 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 843 num outside
# 3
# 843) num outside
# )
# hits normal return
# 843
# 843 is y
# 211 is x
# 4 num outside
# 4
# 44 num outside
# 4
# 446 num outside
# 6
# 446) num outside
# )
# hits normal return
# 446
# 446 is y
# 483 is x
# 6 num outside
# 6
# 64 num outside
# 4
# 646 num outside
# 6
# 646) num outside
# )
# hits normal return
# 646
# 646 is y
# 113 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 924 num outside
# 4
# 924) num outside
# )
# hits normal return
# 924
# 924 is y
# 325 is x
# 2 num outside
# 2
# 20 num outside
# 0
# 209 num outside
# 9
# 209) num outside
# )
# hits normal return
# 209
# 209 is y
# 674 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 229 num outside
# 9
# 229) num outside
# )
# hits normal return
# 229
# 229 is y
# 306 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 16) num outside
# )
# hits normal return
# 16
# 16 is y
# 551 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 752 num outside
# 2
# 752) num outside
# )
# hits normal return
# 752
# 752 is y
# 942 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 567 num outside
# 7
# 567) num outside
# )
# hits normal return
# 567
# 567 is y
# 689 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 888 num outside
# 8
# 888) num outside
# )
# hits normal return
# 888
# 888 is y
# 316 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 35) num outside
# )
# hits normal return
# 35
# 35 is y
# 661 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 456 num outside
# 6
# 456) num outside
# )
# hits normal return
# 456
# 456 is y
# 972 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 157 num outside
# 7
# 157h num outside
# h
# hits value error return
# 0 is y
# 156 is x
# 2 num outside
# 2
# 23 num outside
# 3
# 234 num outside
# 4
# 234) num outside
# )
# hits normal return
# 234
# 234 is y
# 201 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 545 num outside
# 5
# 545) num outside
# )
# hits normal return
# 545
# 545 is y
# 824 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 870 num outside
# 0
# 870) num outside
# )
# hits normal return
# 870
# 870 is y
# 442 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 767 num outside
# 7
# 767) num outside
# )
# hits normal return
# 767
# 767 is y
# 131 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 742 num outside
# 2
# 742) num outside
# )
# hits normal return
# 742
# 742 is y
# 385 is x
# 2 num outside
# 2
# 20 num outside
# 0
# 206 num outside
# 6
# 206) num outside
# )
# hits normal return
# 206
# 206 is y
# 241 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 754 num outside
# 4
# 754) num outside
# )
# hits normal return
# 754
# 754 is y
# 858 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 533 num outside
# 3
# 533{ num outside
# {
# hits value error return
# 0 is y
# 847 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 612 num outside
# 2
# 612w num outside
# w
# hits value error return
# 0 is y
# 89 is x
# 9 num outside
# 9
# 98 num outside
# 8
# 985 num outside
# 5
# 985) num outside
# )
# hits normal return
# 985
# 985 is y
# 256 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 284 num outside
# 4
# 284) num outside
# )
# hits normal return
# 284
# 284 is y
# 845 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 617 num outside
# 7
# 617) num outside
# )
# hits normal return
# 617
# 617 is y
# 814 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 769 num outside
# 9
# 769) num outside
# )
# hits normal return
# 769
# 769 is y
# 685 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 850 num outside
# 0
# 850) num outside
# )
# hits normal return
# 850
# 850 is y
# 142 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 506 num outside
# 6
# 506) num outside
# )
# hits normal return
# 506
# 506 is y
# 0 is x
# a num outside
# a
# hits value error return
# 0 is y
# 2 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 339 num outside
# 9
# 339( num outside
# (
# hits value error return
# 0 is y
# 622 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 831 num outside
# 1
# 831) num outside
# )
# hits normal return
# 831
# 831 is y
# 841 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 258 num outside
# 8
# 258) num outside
# )
# hits normal return
# 258
# 258 is y
# 943 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 197 num outside
# 7
# 197) num outside
# )
# hits normal return
# 197
# 197 is y
# 93 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 185 num outside
# 5
# 185) num outside
# )
# hits normal return
# 185
# 185 is y
# 233 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 470 num outside
# 0
# 470) num outside
# )
# hits normal return
# 470
# 470 is y
# 839 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 164 num outside
# 4
# 164) num outside
# )
# hits normal return
# 164
# 164 is y
# 27 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 58) num outside
# )
# hits normal return
# 58
# 58 is y
# 505 is x
# 7 num outside
# 7
# 7) num outside
# )
# hits normal return
# 7
# 7 is y
# 80 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 504 num outside
# 4
# 504) num outside
# )
# hits normal return
# 504
# 504 is y
# 586 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 784 num outside
# 4
# 784) num outside
# )
# hits normal return
# 784
# 784 is y
# 514 is x
# 9 num outside
# 9
# 90 num outside
# 0
# 909 num outside
# 9
# 909) num outside
# )
# hits normal return
# 909
# 909 is y
# 774 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 957 num outside
# 7
# 957) num outside
# )
# hits normal return
# 957
# 957 is y
# 716 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 576 num outside
# 6
# 576) num outside
# )
# hits normal return
# 576
# 576 is y
# 601 is x
# 9 num outside
# 9
# 93 num outside
# 3
# 939 num outside
# 9
# 939) num outside
# )
# hits normal return
# 939
# 939 is y
# 651 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 869 num outside
# 9
# 869) num outside
# )
# hits normal return
# 869
# 869 is y
# 28 is x
# 2 num outside
# 2
# 23 num outside
# 3
# 23) num outside
# )
# hits normal return
# 23
# 23 is y
# 593 is x
# 6 num outside
# 6
# 60 num outside
# 0
# 606 num outside
# 6
# 606) num outside
# )
# hits normal return
# 606
# 606 is y
# 830 is x
# 4 num outside
# 4
# 42 num outside
# 2
# 421 num outside
# 1
# 421) num outside
# )
# hits normal return
# 421
# 421 is y
# 0 is x
# h num outside
# h
# hits value error return
# 0 is y
# 299 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 889 num outside
# 9
# 889) num outside
# )
# hits normal return
# 889
# 889 is y
# 697 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 774 num outside
# 4
# 774) num outside
# )
# hits normal return
# 774
# 774 is y
# 7 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 535 num outside
# 5
# 535) num outside
# )
# hits normal return
# 535
# 535 is y
# 670 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 193 num outside
# 3
# 193) num outside
# )
# hits normal return
# 193
# 193 is y
# 625 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 519 num outside
# 9
# 519) num outside
# )
# hits normal return
# 519
# 519 is y
# 500 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 263 num outside
# 3
# 263) num outside
# )
# hits normal return
# 263
# 263 is y
# 177 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 618 num outside
# 8
# 618) num outside
# )
# hits normal return
# 618
# 618 is y
# 160 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 633 num outside
# 3
# 633) num outside
# )
# hits normal return
# 633
# 633 is y
# 557 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 511 num outside
# 1
# 511) num outside
# )
# hits normal return
# 511
# 511 is y
# 584 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 586 num outside
# 6
# 586) num outside
# )
# hits normal return
# 586
# 586 is y
# 389 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 417 num outside
# 7
# 417) num outside
# )
# hits normal return
# 417
# 417 is y
# 875 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 721 num outside
# 1
# 721) num outside
# )
# hits normal return
# 721
# 721 is y
# 659 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 634 num outside
# 4
# 634) num outside
# )
# hits normal return
# 634
# 634 is y
# 396 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 299 num outside
# 9
# 299) num outside
# )
# hits normal return
# 299
# 299 is y
# 496 is x
# 2 num outside
# 2
# 20 num outside
# 0
# 203 num outside
# 3
# 203) num outside
# )
# hits normal return
# 203
# 203 is y
# 494 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 285 num outside
# 5
# 285) num outside
# )
# hits normal return
# 285
# 285 is y
# 947 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 673 num outside
# 3
# 673) num outside
# )
# hits normal return
# 673
# 673 is y
# 703 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 883 num outside
# 3
# 883) num outside
# )
# hits normal return
# 883
# 883 is y
# 358 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 599 num outside
# 9
# 599) num outside
# )
# hits normal return
# 599
# 599 is y
# 802 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 575 num outside
# 5
# 575) num outside
# )
# hits normal return
# 575
# 575 is y
# 198 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 240 num outside
# 0
# 240) num outside
# )
# hits normal return
# 240
# 240 is y
# 412 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 618 num outside
# 8
# 618) num outside
# )
# hits normal return
# 618
# 618 is y
# 566 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 368 num outside
# 8
# 368) num outside
# )
# hits normal return
# 368
# 368 is y
# 488 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 165 num outside
# 5
# 165) num outside
# )
# hits normal return
# 165
# 165 is y
# 743 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 549 num outside
# 9
# 549) num outside
# )
# hits normal return
# 549
# 549 is y
# 924 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 355 num outside
# 5
# 355) num outside
# )
# hits normal return
# 355
# 355 is y
# 334 is x
# 9 num outside
# 9
# 93 num outside
# 3
# 934 num outside
# 4
# 934) num outside
# )
# hits normal return
# 934
# 934 is y
# 244 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 156 num outside
# 6
# 156) num outside
# )
# hits normal return
# 156
# 156 is y
# 139 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 569 num outside
# 9
# 569) num outside
# )
# hits normal return
# 569
# 569 is y
# 551 is x
# 2 num outside
# 2
# 27 num outside
# 7
# 270 num outside
# 0
# 270) num outside
# )
# hits normal return
# 270
# 270 is y
# 79 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 597 num outside
# 7
# 597) num outside
# )
# hits normal return
# 597
# 597 is y
# 0 is x
# l num outside
# l
# hits value error return
# 0 is y
# 865 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 591 num outside
# 1
# 591) num outside
# )
# hits normal return
# 591
# 591 is y
# 787 is x
# 9 num outside
# 9
# 97 num outside
# 7
# 971 num outside
# 1
# 971) num outside
# )
# hits normal return
# 971
# 971 is y
# 609 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 411 num outside
# 1
# 411) num outside
# )
# hits normal return
# 411
# 411 is y
# 452 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 921 num outside
# 1
# 921) num outside
# )
# hits normal return
# 921
# 921 is y
# 673 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 185 num outside
# 5
# 185) num outside
# )
# hits normal return
# 185
# 185 is y
# 205 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 923 num outside
# 3
# 923) num outside
# )
# hits normal return
# 923
# 923 is y
# 625 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 543 num outside
# 3
# 543) num outside
# )
# hits normal return
# 543
# 543 is y
# 476 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 415 num outside
# 5
# 415) num outside
# )
# hits normal return
# 415
# 415 is y
# 223 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 252 num outside
# 2
# 252) num outside
# )
# hits normal return
# 252
# 252 is y
# 0 is x
# w num outside
# w
# hits value error return
# 0 is y
# 889 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 926 num outside
# 6
# 926) num outside
# )
# hits normal return
# 926
# 926 is y
# 614 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 769 num outside
# 9
# 769) num outside
# )
# hits normal return
# 769
# 769 is y
# 848 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 630 num outside
# 0
# 630) num outside
# )
# hits normal return
# 630
# 630 is y
# 700 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 475 num outside
# 5
# 475) num outside
# )
# hits normal return
# 475
# 475 is y
# 455 is x
# 9 num outside
# 9
# 99 num outside
# 9
# 994 num outside
# 4
# 994) num outside
# )
# hits normal return
# 994
# 994 is y
# 727 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 255 num outside
# 5
# 255) num outside
# )
# hits normal return
# 255
# 255 is y
# 814 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 330 num outside
# 0
# 330) num outside
# )
# hits normal return
# 330
# 330 is y
# 45 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 143 num outside
# 3
# 143) num outside
# )
# hits normal return
# 143
# 143 is y
# 571 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 876 num outside
# 6
# 876) num outside
# )
# hits normal return
# 876
# 876 is y
# 491 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 788 num outside
# 8
# 788) num outside
# )
# hits normal return
# 788
# 788 is y
# 41 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 365 num outside
# 5
# 365) num outside
# )
# hits normal return
# 365
# 365 is y
# 905 is x
# 1 num outside
# 1
# 18 num outside
# 8
# 180 num outside
# 0
# 180) num outside
# )
# hits normal return
# 180
# 180 is y
# 0 is x
# l num outside
# l
# hits value error return
# 0 is y
# 246 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 147 num outside
# 7
# 147) num outside
# )
# hits normal return
# 147
# 147 is y
# 381 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 509 num outside
# 9
# 509) num outside
# )
# hits normal return
# 509
# 509 is y
# 897 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 597 num outside
# 7
# 597) num outside
# )
# hits normal return
# 597
# 597 is y
# 860 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 194 num outside
# 4
# 194w num outside
# w
# hits value error return
# 0 is y
# 593 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 225 num outside
# 5
# 225) num outside
# )
# hits normal return
# 225
# 225 is y
# 771 is x
# 8 num outside
# 8
# 84 num outside
# 4
# 843 num outside
# 3
# 843) num outside
# )
# hits normal return
# 843
# 843 is y
# 764 is x
# 9 num outside
# 9
# 96 num outside
# 6
# 968 num outside
# 8
# 968) num outside
# )
# hits normal return
# 968
# 968 is y
# 696 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 330 num outside
# 0
# 330) num outside
# )
# hits normal return
# 330
# 330 is y
# 154 is x
# 4 num outside
# 4
# 41 num outside
# 1
# 412 num outside
# 2
# 412) num outside
# )
# hits normal return
# 412
# 412 is y
# 426 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 382 num outside
# 2
# 382) num outside
# )
# hits normal return
# 382
# 382 is y
# 990 is x
# 3 num outside
# 3
# 3) num outside
# )
# hits normal return
# 3
# 3 is y
# 290 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 926 num outside
# 6
# 926) num outside
# )
# hits normal return
# 926
# 926 is y
# 900 is x
# 4 num outside
# 4
# 40 num outside
# 0
# 408 num outside
# 8
# 408) num outside
# )
# hits normal return
# 408
# 408 is y
# 932 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 523 num outside
# 3
# 523) num outside
# )
# hits normal return
# 523
# 523 is y
# 477 is x
# 8 num outside
# 8
# 86 num outside
# 6
# 866 num outside
# 6
# 866) num outside
# )
# hits normal return
# 866
# 866 is y
# 14 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 199 num outside
# 9
# 199) num outside
# )
# hits normal return
# 199
# 199 is y
# 637 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 958 num outside
# 8
# 958) num outside
# )
# hits normal return
# 958
# 958 is y
# 777 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 762 num outside
# 2
# 762) num outside
# )
# hits normal return
# 762
# 762 is y
# 194 is x
# 4 num outside
# 4
# 47 num outside
# 7
# 474 num outside
# 4
# 474) num outside
# )
# hits normal return
# 474
# 474 is y
# 521 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 703 num outside
# 3
# 703) num outside
# )
# hits normal return
# 703
# 703 is y
# 897 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 954 num outside
# 4
# 954) num outside
# )
# hits normal return
# 954
# 954 is y
# 660 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 652 num outside
# 2
# 652) num outside
# )
# hits normal return
# 652
# 652 is y
# 488 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 877 num outside
# 7
# 877) num outside
# )
# hits normal return
# 877
# 877 is y
# 899 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 223 num outside
# 3
# 223) num outside
# )
# hits normal return
# 223
# 223 is y
# 799 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 584 num outside
# 4
# 584) num outside
# )
# hits normal return
# 584
# 584 is y
# 0 is x
# ] num outside
# ]
# hits value error return
# 0 is y
# 381 is x
# 1 num outside
# 1
# 12 num outside
# 2
# 120 num outside
# 0
# 120) num outside
# )
# hits normal return
# 120
# 120 is y
# 97 is x
# 1 num outside
# 1
# 10 num outside
# 0
# 101 num outside
# 1
# 101) num outside
# )
# hits normal return
# 101
# 101 is y
# 448 is x
# 4 num outside
# 4
# 48 num outside
# 8
# 487 num outside
# 7
# 487) num outside
# )
# hits normal return
# 487
# 487 is y
# 36 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 815 num outside
# 5
# 815) num outside
# )
# hits normal return
# 815
# 815 is y
# 35 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 211 num outside
# 1
# 211) num outside
# )
# hits normal return
# 211
# 211 is y
# 288 is x
# 9 num outside
# 9
# 99 num outside
# 9
# 994 num outside
# 4
# 994) num outside
# )
# hits normal return
# 994
# 994 is y
# 291 is x
# 7 num outside
# 7
# 73 num outside
# 3
# 734 num outside
# 4
# 734) num outside
# )
# hits normal return
# 734
# 734 is y
# 80 is x
# 6 num outside
# 6
# 66 num outside
# 6
# 663 num outside
# 3
# 663) num outside
# )
# hits normal return
# 663
# 663 is y
# 288 is x
# 1 num outside
# 1
# 19 num outside
# 9
# 196 num outside
# 6
# 196) num outside
# )
# hits normal return
# 196
# 196 is y
# 153 is x
# 2 num outside
# 2
# 20 num outside
# 0
# 200 num outside
# 0
# 200) num outside
# )
# hits normal return
# 200
# 200 is y
# 463 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 573 num outside
# 3
# 573w num outside
# w
# hits value error return
# 0 is y
# 842 is x
# ...
# 5 num outside
# 5
# 53 num outside
# 3
# 537 num outside
# 7
# 537) num outside
# )
# hits normal return
# 537
# 537 is y
# 350 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 45) num outside
# )
# hits normal return
# 45
# 45 is y
# 392 is x
# 7 num outside
# 7
# 74 num outside
# 4
# 743 num outside
# 3
# 743) num outside
# )
# hits normal return
# 743
# 743 is y
# 639 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 758 num outside
# 8
# 758) num outside
# )
# hits normal return
# 758
# 758 is y
# 342 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 243 num outside
# 3
# 243) num outside
# )
# hits normal return
# 243
# 243 is y
# 107 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 290 num outside
# 0
# 290) num outside
# )
# hits normal return
# 290
# 290 is y
# 76 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 140 num outside
# 0
# 140) num outside
# )
# hits normal return
# 140
# 140 is y
# 207 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 882 num outside
# 2
# 882) num outside
# )
# hits normal return
# 882
# 882 is y
# 448 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 652 num outside
# 2
# 652' num outside
# '
# hits value error return
# 0 is y
# 509 is x
# 5 num outside
# 5
# 54 num outside
# 4
# 549 num outside
# 9
# 549) num outside
# )
# hits normal return
# 549
# 549 is y
# 657 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 688 num outside
# 8
# 688) num outside
# )
# hits normal return
# 688
# 688 is y
# 0 is x
# ( num outside
# (
# hits value error return
# 0 is y
# 172 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 314 num outside
# 4
# 314) num outside
# )
# hits normal return
# 314
# 314 is y
# 666 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 262 num outside
# 2
# 262) num outside
# )
# hits normal return
# 262
# 262 is y
# 215 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 760 num outside
# 0
# 760) num outside
# )
# hits normal return
# 760
# 760 is y
# 301 is x
# 5 num outside
# 5
# 52 num outside
# 2
# 529 num outside
# 9
# 529) num outside
# )
# hits normal return
# 529
# 529 is y
# 944 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 345 num outside
# 5
# 345) num outside
# )
# hits normal return
# 345
# 345 is y
# 174 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 53) num outside
# )
# hits normal return
# 53
# 53 is y
# 305 is x
# 4 num outside
# 4
# 42 num outside
# 2
# 421 num outside
# 1
# 421) num outside
# )
# hits normal return
# 421
# 421 is y
# 82 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 32) num outside
# )
# hits normal return
# 32
# 32 is y
# 818 is x
# 5 num outside
# 5
# 55 num outside
# 5
# 551 num outside
# 1
# 551[ num outside
# [
# hits value error return
# 0 is y
# 465 is x
# 9 num outside
# 9
# 98 num outside
# 8
# 988 num outside
# 8
# 988) num outside
# )
# hits normal return
# 988
# 988 is y
# 486 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 789 num outside
# 9
# 789) num outside
# )
# hits normal return
# 789
# 789 is y
# 419 is x
# 2 num outside
# 2
# 20 num outside
# 0
# 207 num outside
# 7
# 207) num outside
# )
# hits normal return
# 207
# 207 is y
# 13 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 167 num outside
# 7
# 167) num outside
# )
# hits normal return
# 167
# 167 is y
# 24 is x
# 3 num outside
# 3
# 37 num outside
# 7
# 374 num outside
# 4
# 374) num outside
# )
# hits normal return
# 374
# 374 is y
# 932 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 568 num outside
# 8
# 568) num outside
# )
# hits normal return
# 568
# 568 is y
# 100 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 246 num outside
# 6
# 246) num outside
# )
# hits normal return
# 246
# 246 is y
# 743 is x
# 4 num outside
# 4
# 46 num outside
# 6
# 461 num outside
# 1
# 461) num outside
# )
# hits normal return
# 461
# 461 is y
# 733 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 280 num outside
# 0
# 280) num outside
# )
# hits normal return
# 280
# 280 is y
# 397 is x
# 9 num outside
# 9
# 95 num outside
# 5
# 950 num outside
# 0
# 950) num outside
# )
# hits normal return
# 950
# 950 is y
# 921 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 777 num outside
# 7
# 777) num outside
# )
# hits normal return
# 777
# 777 is y
# 513 is x
# 7 num outside
# 7
# 78 num outside
# 8
# 785 num outside
# 5
# 785) num outside
# )
# hits normal return
# 785
# 785 is y
# 656 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 887 num outside
# 7
# 887) num outside
# )
# hits normal return
# 887
# 887 is y
# 589 is x
# 9 num outside
# 9
# 96 num outside
# 6
# 966 num outside
# 6
# 966) num outside
# )
# hits normal return
# 966
# 966 is y
# 287 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 686 num outside
# 6
# 686) num outside
# )
# hits normal return
# 686
# 686 is y
# 4 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 157 num outside
# 7
# 157) num outside
# )
# hits normal return
# 157
# 157 is y
# 617 is x
# 3 num outside
# 3
# 34 num outside
# 4
# 343 num outside
# 3
# 343) num outside
# )
# hits normal return
# 343
# 343 is y
# 271 is x
# 5 num outside
# 5
# 55 num outside
# 5
# 55) num outside
# )
# hits normal return
# 55
# 55 is y
# 582 is x
# 6 num outside
# 6
# 64 num outside
# 4
# 649 num outside
# 9
# 649) num outside
# )
# hits normal return
# 649
# 649 is y
# 0 is x
# h num outside
# h
# hits value error return
# 0 is y
# 659 is x
# 6 num outside
# 6
# 68 num outside
# 8
# 68) num outside
# )
# hits normal return
# 68
# 68 is y
# 373 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 308 num outside
# 8
# 308) num outside
# )
# hits normal return
# 308
# 308 is y
# 572 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 701 num outside
# 1
# 701) num outside
# )
# hits normal return
# 701
# 701 is y
# 30 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 709 num outside
# 9
# 709) num outside
# )
# hits normal return
# 709
# 709 is y
# 353 is x
# 2 num outside
# 2
# 24 num outside
# 4
# 243 num outside
# 3
# 243) num outside
# )
# hits normal return
# 243
# 243 is y
# 63 is x
# 4 num outside
# 4
# 49 num outside
# 9
# 496 num outside
# 6
# 496) num outside
# )
# hits normal return
# 496
# 496 is y
# 137 is x
# 3 num outside
# 3
# 33 num outside
# 3
# 334 num outside
# 4
# 334) num outside
# )
# hits normal return
# 334
# 334 is y
# 991 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 76) num outside
# )
# hits normal return
# 76
# 76 is y
# 485 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 797 num outside
# 7
# 797) num outside
# )
# hits normal return
# 797
# 797 is y
# 636 is x
# 7 num outside
# 7
# 71 num outside
# 1
# 71) num outside
# )
# hits normal return
# 71
# 71 is y
# 774 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 387 num outside
# 7
# 387) num outside
# )
# hits normal return
# 387
# 387 is y
# 418 is x
# 1 num outside
# 1
# 12 num outside
# 2
# 125 num outside
# 5
# 125) num outside
# )
# hits normal return
# 125
# 125 is y
# 256 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 560 num outside
# 0
# 560) num outside
# )
# hits normal return
# 560
# 560 is y
# 631 is x
# 2 num outside
# 2
# 27 num outside
# 7
# 272 num outside
# 2
# 272) num outside
# )
# hits normal return
# 272
# 272 is y
# 713 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 265 num outside
# 5
# 265) num outside
# )
# hits normal return
# 265
# 265 is y
# 792 is x
# 5 num outside
# 5
# 57 num outside
# 7
# 576 num outside
# 6
# 576) num outside
# )
# hits normal return
# 576
# 576 is y
# 146 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 670 num outside
# 0
# 670) num outside
# )
# hits normal return
# 670
# 670 is y
# 73 is x
# 1 num outside
# 1
# 11 num outside
# 1
# 111 num outside
# 1
# 111) num outside
# )
# hits normal return
# 111
# 111 is y
# 820 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 581 num outside
# 1
# 581) num outside
# )
# hits normal return
# 581
# 581 is y
# 899 is x
# 6 num outside
# 6
# 64 num outside
# 4
# 649 num outside
# 9
# 649) num outside
# )
# hits normal return
# 649
# 649 is y
# 230 is x
# 8 num outside
# 8
# 88 num outside
# 8
# 883 num outside
# 3
# 883) num outside
# )
# hits normal return
# 883
# 883 is y
# 145 is x
# 7 num outside
# 7
# 72 num outside
# 2
# 724 num outside
# 4
# 724) num outside
# )
# hits normal return
# 724
# 724 is y
# 424 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 670 num outside
# 0
# 670) num outside
# )
# hits normal return
# 670
# 670 is y
# 514 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 265 num outside
# 5
# 265w num outside
# w
# hits value error return
# 0 is y
# 804 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 700 num outside
# 0
# 700) num outside
# )
# hits normal return
# 700
# 700 is y
# 28 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 284 num outside
# 4
# 284) num outside
# )
# hits normal return
# 284
# 284 is y
# 930 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 21) num outside
# )
# hits normal return
# 21
# 21 is y
# 119 is x
# 5 num outside
# 5
# 58 num outside
# 8
# 587 num outside
# 7
# 587) num outside
# )
# hits normal return
# 587
# 587 is y
# 366 is x
# 6 num outside
# 6
# 63 num outside
# 3
# 632 num outside
# 2
# 632) num outside
# )
# hits normal return
# 632
# 632 is y
# 710 is x
# 9 num outside
# 9
# 99 num outside
# 9
# 996 num outside
# 6
# 996) num outside
# )
# hits normal return
# 996
# 996 is y
# 427 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 253 num outside
# 3
# 253) num outside
# )
# hits normal return
# 253
# 253 is y
# 486 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 35) num outside
# )
# hits normal return
# 35
# 35 is y
# 522 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 764 num outside
# 4
# 764) num outside
# )
# hits normal return
# 764
# 764 is y
# 755 is x
# 7 num outside
# 7
# 79 num outside
# 9
# 793 num outside
# 3
# 793) num outside
# )
# hits normal return
# 793
# 793 is y
# 685 is x
# 6 num outside
# 6
# 62 num outside
# 2
# 620 num outside
# 0
# 620) num outside
# )
# hits normal return
# 620
# 620 is y
# 763 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 532 num outside
# 2
# 532) num outside
# )
# hits normal return
# 532
# 532 is y
# 157 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 853 num outside
# 3
# 853) num outside
# )
# hits normal return
# 853
# 853 is y
# 376 is x
# 5 num outside
# 5
# 53 num outside
# 3
# 536 num outside
# 6
# 536) num outside
# )
# hits normal return
# 536
# 536 is y
# 280 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 439 num outside
# 9
# 439) num outside
# )
# hits normal return
# 439
# 439 is y
# 368 is x
# 6 num outside
# 6
# 69 num outside
# 9
# 692 num outside
# 2
# 692) num outside
# )
# hits normal return
# 692
# 692 is y
# 233 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 760 num outside
# 0
# 760) num outside
# )
# hits normal return
# 760
# 760 is y
# 489 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 225 num outside
# 5
# 225) num outside
# )
# hits normal return
# 225
# 225 is y
# 977 is x
# 9 num outside
# 9
# 94 num outside
# 4
# 940 num outside
# 0
# 940) num outside
# )
# hits normal return
# 940
# 940 is y
# 124 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 752 num outside
# 2
# 752) num outside
# )
# hits normal return
# 752
# 752 is y
# 483 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 254 num outside
# 4
# 254) num outside
# )
# hits normal return
# 254
# 254 is y
# 23 is x
# 2 num outside
# 2
# 26 num outside
# 6
# 268 num outside
# 8
# 268) num outside
# )
# hits normal return
# 268
# 268 is y
# 48 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 566 num outside
# 6
# 566) num outside
# )
# hits normal return
# 566
# 566 is y
# 879 is x
# 4 num outside
# 4
# 40 num outside
# 0
# 408 num outside
# 8
# 408) num outside
# )
# hits normal return
# 408
# 408 is y
# 633 is x
# 3 num outside
# 3
# 36 num outside
# 6
# 365 num outside
# 5
# 365) num outside
# )
# hits normal return
# 365
# 365 is y
# 135 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 837 num outside
# 7
# 837) num outside
# )
# hits normal return
# 837
# 837 is y
# 347 is x
# 3 num outside
# 3
# 31 num outside
# 1
# 314 num outside
# 4
# 314) num outside
# )
# hits normal return
# 314
# 314 is y
# 301 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 516 num outside
# 6
# 516) num outside
# )
# hits normal return
# 516
# 516 is y
# 883 is x
# 4 num outside
# 4
# 46 num outside
# 6
# 466 num outside
# 6
# 466) num outside
# )
# hits normal return
# 466
# 466 is y
# 273 is x
# 7 num outside
# 7
# 75 num outside
# 5
# 756 num outside
# 6
# 756) num outside
# )
# hits normal return
# 756
# 756 is y
# 89 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 229 num outside
# 9
# 229) num outside
# )
# hits normal return
# 229
# 229 is y
# 622 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 308 num outside
# 8
# 308) num outside
# )
# hits normal return
# 308
# 308 is y
# 941 is x
# 4 num outside
# 4
# 42 num outside
# 2
# 422 num outside
# 2
# 422) num outside
# )
# hits normal return
# 422
# 422 is y
# 815 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 766 num outside
# 6
# 766) num outside
# )
# hits normal return
# 766
# 766 is y
# 115 is x
# 8 num outside
# 8
# 81 num outside
# 1
# 810 num outside
# 0
# 810) num outside
# )
# hits normal return
# 810
# 810 is y
# 969 is x
# 8 num outside
# 8
# 80 num outside
# 0
# 807 num outside
# 7
# 807) num outside
# )
# hits normal return
# 807
# 807 is y
# 206 is x
# 3 num outside
# 3
# 32 num outside
# 2
# 32) num outside
# )
# hits normal return
# 32
# 32 is y
# 143 is x
# 8 num outside
# 8
# 85 num outside
# 5
# 854 num outside
# 4
# 854) num outside
# )
# hits normal return
# 854
# 854 is y
# 409 is x
# 1 num outside
# 1
# 14 num outside
# 4
# 145 num outside
# 5
# 145) num outside
# )
# hits normal return
# 145
# 145 is y
# 728 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 456 num outside
# 6
# 456) num outside
# )
# hits normal return
# 456
# 456 is y
# 904 is x
# 5 num outside
# 5
# 56 num outside
# 6
# 568 num outside
# 8
# 568) num outside
# )
# hits normal return
# 568
# 568 is y
# 349 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 775 num outside
# 5
# 775) num outside
# )
# hits normal return
# 775
# 775 is y
# 286 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 875 num outside
# 5
# 875) num outside
# )
# hits normal return
# 875
# 875 is y
# 279 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 388 num outside
# 8
# 388) num outside
# )
# hits normal return
# 388
# 388 is y
# 81 is x
# 8 num outside
# 8
# 82 num outside
# 2
# 823 num outside
# 3
# 823) num outside
# )
# hits normal return
# 823
# 823 is y
# 443 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 168 num outside
# 8
# 168) num outside
# )
# hits normal return
# 168
# 168 is y
# 475 is x
# 2 num outside
# 2
# 22 num outside
# 2
# 220 num outside
# 0
# 220) num outside
# )
# hits normal return
# 220
# 220 is y
# 651 is x
# 4 num outside
# 4
# 45 num outside
# 5
# 45) num outside
# )
# hits normal return
# 45
# 45 is y
# 837 is x
# 9 num outside
# 9
# 91 num outside
# 1
# 911 num outside
# 1
# 911) num outside
# )
# hits normal return
# 911
# 911 is y
# 699 is x
# 3 num outside
# 3
# 37 num outside
# 7
# 375 num outside
# 5
# 375) num outside
# )
# hits normal return
# 375
# 375 is y
# 936 is x
# 7 num outside
# 7
# 77 num outside
# 7
# 779 num outside
# 9
# 779) num outside
# )
# hits normal return
# 779
# 779 is y
# 928 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 258 num outside
# 8
# 258) num outside
# )
# hits normal return
# 258
# 258 is y
# 65 is x
# 1 num outside
# 1
# 10 num outside
# 0
# 102 num outside
# 2
# 102) num outside
# )
# hits normal return
# 102
# 102 is y
# 517 is x
# 4 num outside
# 4
# 48 num outside
# 8
# 48) num outside
# )
# hits normal return
# 48
# 48 is y
# 846 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 43) num outside
# )
# hits normal return
# 43
# 43 is y
# 77 is x
# 7 num outside
# 7
# 70 num outside
# 0
# 705 num outside
# 5
# 705) num outside
# )
# hits normal return
# 705
# 705 is y
# 885 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 675 num outside
# 5
# 675) num outside
# )
# hits normal return
# 675
# 675 is y
# 180 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 761 num outside
# 1
# 761) num outside
# )
# hits normal return
# 761
# 761 is y
# 743 is x
# 8 num outside
# 8
# 82 num outside
# 2
# 829 num outside
# 9
# 829) num outside
# )
# hits normal return
# 829
# 829 is y
# 99 is x
# 6 num outside
# 6
# 67 num outside
# 7
# 676 num outside
# 6
# 676) num outside
# )
# hits normal return
# 676
# 676 is y
# 223 is x
# 2 num outside
# 2
# 28 num outside
# 8
# 288 num outside
# 8
# 288) num outside
# )
# hits normal return
# 288
# 288 is y
# 358 is x
# 7 num outside
# 7
# 71 num outside
# 1
# 710 num outside
# 0
# 710) num outside
# )
# hits normal return
# 710
# 710 is y
# 336 is x
# 5 num outside
# 5
# 50 num outside
# 0
# 503 num outside
# 3
# 503) num outside
# )
# hits normal return
# 503
# 503 is y
# 412 is x
# 5 num outside
# 5
# 55 num outside
# 5
# 553 num outside
# 3
# 553) num outside
# )
# hits normal return
# 553
# 553 is y
# 824 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 352 num outside
# 2
# 352) num outside
# )
# hits normal return
# 352
# 352 is y
# 282 is x
# 9 num outside
# 9
# 92 num outside
# 2
# 920 num outside
# 0
# 920) num outside
# )
# hits normal return
# 920
# 920 is y
# 252 is x
# 2 num outside
# 2
# 21 num outside
# 1
# 21) num outside
# )
# hits normal return
# 21
# 21 is y
# 958 is x
# 6 num outside
# 6
# 61 num outside
# 1
# 613 num outside
# 3
# 613) num outside
# )
# hits normal return
# 613
# 613 is y
# 696 is x
# 8 num outside
# 8
# 87 num outside
# 7
# 876 num outside
# 6
# 876) num outside
# )
# hits normal return
# 876
# 876 is y
# 761 is x
# 2 num outside
# 2
# 29 num outside
# 9
# 290 num outside
# 0
# 290) num outside
# )
# hits normal return
# 290
# 290 is y
# 971 is x
# 1 num outside
# 1
# 16 num outside
# 6
# 166 num outside
# 6
# 166) num outside
# )
# hits normal return
# 166
# 166 is y
# 761 is x
# 3 num outside
# 3
# 35 num outside
# 5
# 359 num outside
# 9
# 359) num outside
# )
# hits normal return
# 359
# 359 is y
# 349 is x
# 1 num outside
# 1
# 15 num outside
# 5
# 153 num outside
# 3
# 153) num outside
# )
# hits normal return
# 153
# 153 is y
# 640 is x
# 5 num outside
# 5
# 51 num outside
# 1
# 511 num outside
# 1
# 511) num outside
# )
# hits normal return
# 511
# 511 is y
# 472 is x
# 8 num outside
# 8
# 83 num outside
# 3
# 839 num outside
# 9
# 839) num outside
# )
# hits normal return
# 839
# 839 is y
# 823 is x
# 3 num outside
# 3
# 30 num outside
# 0
# 302 num outside
# 2
# 302) num outside
# )
# hits normal return
# 302
# 302 is y
# 255 is x
# 4 num outside
# 4
# 43 num outside
# 3
# 432 num outside
# 2
# 432) num outside
# )
# hits normal return
# 432
# 432 is y
# 30 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 380 num outside
# 0
# 380) num outside
# )
# hits normal return
# 380
# 380 is y
# 852 is x
# 6 num outside
# 6
# 65 num outside
# 5
# 651 num outside
# 1
# 651) num outside
# )
# hits normal return
# 651
# 651 is y
# 683 is x
# 3 num outside
# 3
# 38 num outside
# 8
# 385 num outside
# 5
# 385) num outside
# )
# hits normal return
# 385
# 385 is y
# 988 is x
# 5 num outside
# 5
# 59 num outside
# 9
# 590 num outside
# 0
# 590) num outside
# )
# hits normal return
# 590
# 590 is y
# 608 is x
# 2 num outside
# 2
# 25 num outside
# 5
# 251 num outside
# 1
# 251) num outside
# )
# hits normal return
# 251
# 251 is y
# 992 is x
# 7 num outside
# 7
# 76 num outside
# 6
# 768 num outside
# 8
# 768) num outside
# )
# hits normal return
# 768
# 768 is y
# 175595659

# %%
a = "24}"
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 2
#       1 a = "24}"
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: '24}'
